# %% [markdown]
# # Vector Operations
#
# $~$
#
# Use the following interactive tool to visualize summation of two-dimensional vectors:

# %% [markdown]
# ```{raw} html
# <iframe src="../interactive/vector-addition.html" width="100%" height="1450"></iframe>
# ```

# %%
from jupyterquiz import display_quiz
git_url='https://raw.githubusercontent.com/jmshea/Linear-Algebra-for-Data-Science-with-Python/main/'
dir = '02-vectors/'

# %% [markdown]
# **Self-Assessment:**
#
# The following question can be used to check your understanding of the material covered in Section 2.5 of *Linear Algebra for Data Science with Python*.

# %%
file = 'questions/5-1-vector-addition.json'
display_quiz(file, num=3, shuffle_questions=True)
# Out:
# <div id="YnvMOyxVXaft" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="3" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #YnvMOyxVXaft {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=3, shuffle_questions=True, colors='fdsp')
# Out:
# <div id="NcMowPOijEwp" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="3" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #NcMowPOijEwp {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
file = 'questions/5-2-scalar-vector-mult.json'
display_quiz(file, num=2, shuffle_questions=True)
# Out:
# <div id="bAqiTqBycBdM" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #bAqiTqBycBdM {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="SXbzffARsjAf" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #SXbzffARsjAf {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
file = 'questions/5-3-vector-subtraction.json'
display_quiz(file, num=2, shuffle_questions=True)
# Out:
# <div id="HlylzdjuHRYS" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #HlylzdjuHRYS {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="agZwXZVHrmzN" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #agZwXZVHrmzN {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
file = 'questions/5-4-hadamard-prod.json'
display_quiz(file, num=2, shuffle_questions=True)
# Out:
# <div id="RlttKuCyGWqU" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #RlttKuCyGWqU {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="NeJMBtvGNEUA" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #NeJMBtvGNEUA {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="lyzOvvjHDqQm" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #lyzOvvjHDqQm {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
file = 'questions/5-5-dot-prod.json'
display_quiz(file, num=2, shuffle_questions=True)
# Out:
# <div id="YEzezfLRSWyn" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #YEzezfLRSWyn {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="omJfGLljwkAu" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #omJfGLljwkAu {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
file = 'questions/5-6-norm.json'
display_quiz(file, num=2, shuffle_questions=True)
# Out:
# <div id="bSsIoaRCTioJ" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #bSsIoaRCTioJ {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="PTsFBuzjLGfy" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #PTsFBuzjLGfy {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
file = 'questions/5-7-normalized-vecs.json'
display_quiz(file, num=2, shuffle_questions=True)
# Out:
# <div id="IKYDTSsTFDYO" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #IKYDTSsTFDYO {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="aUxfuhomAIBO" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #aUxfuhomAIBO {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
file = 'questions/5-8-vec-dist.json'
display_quiz(file, num=2, shuffle_questions=True)
# Out:
# <div id="CIrrhiHwdMoV" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #CIrrhiHwdMoV {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
display_quiz(git_url + dir + file, num=2, shuffle_questions=True,
             colors='fdsp', load_js=False)
# Out:
# <div id="nsbJgTKLNRCs" data-shufflequestions="True" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #nsbJgTKLNRCs {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
# ...

# %%
from jupytercards import display_flashcards

display_flashcards('flashcards/' + '5-vector-ops.json')
# Out:
# <style>
# :root{
#   --asparagus: #87a878ff;
#   --terra-cotta: #e26d5aff;
#   --cyan-process: #5bc0ebff;
#   --dark-blue-gray: #666a86ff;
#   --snow: #fffafbff;
#   --rich-black-fogra-39: #090c08ff;
# }
#
#
# /* entire container, keeps perspective */
# .flip-container {
# 	perspective: 1000px;
#   touch-action: pinch-zoom pan-y;
# }
#
#
# .flip-container.flip .flipper {
#     box-sizing: content-box;
# 	  transform: rotateY(180deg);
# 	/* transform: rotateY(180deg)  translateX(-6%);  */
# }
#
#
# .flip-container.slide .flipper.frontcard {
#     filter: brightness(90%);
#     position:absolute;
#     z-index: -20;
#     /* left: 20px; */
# }
#
# .flip-container.prepare .flipper.backcard {
#     opacity:1;
#     transition: display 0s;
#     transform:  translateX(20px);
# }
#
#
# .flip-container.slide .flipper.backcard {
#     filter: brightness(115%);
#     /* height: 360px; */
#     opacity:1;
# ...

# %%
git_url='https://raw.githubusercontent.com/jmshea/Linear-Algebra-for-Data-Science-with-Python/main/'
git_dir ='02-vectors/flashcards/'
display_flashcards(git_url + git_dir +'5-vector-ops.json')
# Out:
# <style>
# :root{
#   --asparagus: #87a878ff;
#   --terra-cotta: #e26d5aff;
#   --cyan-process: #5bc0ebff;
#   --dark-blue-gray: #666a86ff;
#   --snow: #fffafbff;
#   --rich-black-fogra-39: #090c08ff;
# }
#
#
# /* entire container, keeps perspective */
# .flip-container {
# 	perspective: 1000px;
#   touch-action: pinch-zoom pan-y;
# }
#
#
# .flip-container.flip .flipper {
#     box-sizing: content-box;
# 	  transform: rotateY(180deg);
# 	/* transform: rotateY(180deg)  translateX(-6%);  */
# }
#
#
# .flip-container.slide .flipper.frontcard {
#     filter: brightness(90%);
#     position:absolute;
#     z-index: -20;
#     /* left: 20px; */
# }
#
# .flip-container.prepare .flipper.backcard {
#     opacity:1;
#     transition: display 0s;
#     transform:  translateX(20px);
# }
#
#
# .flip-container.slide .flipper.backcard {
#     filter: brightness(115%);
#     /* height: 360px; */
#     opacity:1;
# ...
